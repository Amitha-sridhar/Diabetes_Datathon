# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfGDData=pd.read_excel("Gestational Diabetes Data.xlsx",sheet_name = "Data")

# %%
dfGDData
# Out:
#      Participant ID  25OHD checked yes (1) or no (0)  Screened 10 2  GCT10 2  \
# 0                 1                              NaN              1        0
# 1                 2                              NaN              1        1
# 2                 3                              NaN              1        1
# 3                 4                              NaN              1        0
# 4                 5                              NaN              1        0
# ..              ...                              ...            ...      ...
# 595             596                              1.0              1        0
# 596             597                              0.0              1        0
# 597             598                              1.0              1        1
# 598             599                              0.0              1        1
# 599             600                              1.0              1        0
#
# ...

# %%
dfGDData.head()
# Out:
#    Participant ID  25OHD checked yes (1) or no (0)  Screened 10 2  GCT10 2  \
# 0               1                              NaN              1        0
# 1               2                              NaN              1        1
# 2               3                              NaN              1        1
# 3               4                              NaN              1        0
# 4               5                              NaN              1        0
#
#   Date Form Signed  systolic BP (mmHg) V1  diastolic BP (mmHg) V1  \
# 0       2013-10-02                    114                      58
# 1       2013-10-02                    178                      78
# 2       2013-10-02                    123                      62
# 3       2013-10-09                    115                      68
# 4       2013-10-09                    116                      61
#
#    Pulse (bpm) V1  Weight (kg) V1  Height (cm) V1  ...  Cleft Lip  \
# ...

# %%
dfGDData.tail()
# Out:
#      Participant ID  25OHD checked yes (1) or no (0)  Screened 10 2  GCT10 2  \
# 595             596                              1.0              1        0
# 596             597                              0.0              1        0
# 597             598                              1.0              1        1
# 598             599                              0.0              1        1
# 599             600                              1.0              1        0
#
#     Date Form Signed  systolic BP (mmHg) V1  diastolic BP (mmHg) V1  \
# 595       2015-11-04                    127                      72
# 596       2015-11-04                    138                      63
# 597       2015-11-04                    115                      69
# 598       2015-11-04                    129                      69
# 599       2015-11-11                    110                      53
#
#      Pulse (bpm) V1  Weight (kg) V1  Height (cm) V1  ...  Cleft Lip  \
# ...

# %%
dfGDData.T
# Out:
#                                                  0                    1    \
# Participant ID                                     1                    2
# 25OHD checked yes (1) or no (0)                  NaN                  NaN
# Screened 10 2                                      1                    1
# GCT10 2                                            0                    1
# Date Form Signed                 2013-10-02 00:00:00  2013-10-02 00:00:00
# ...                                              ...                  ...
# Transposition of Great arteries                   No                   No
# Septal defect                                     No                   No
# Other cardiac anomaly                             No                   No
# Epidural                                         NaN                  NaN
# Spinal                                           NaN                  NaN
#
#                                                  2                    3    \
# ...

# %%
dfGDData.size
# Out:
# 155400

# %%
dfGDData.describe
# Out:
# <bound method NDFrame.describe of      Participant ID  25OHD checked yes (1) or no (0)  Screened 10 2  GCT10 2  \
# 0                 1                              NaN              1        0
# 1                 2                              NaN              1        1
# 2                 3                              NaN              1        1
# 3                 4                              NaN              1        0
# 4                 5                              NaN              1        0
# ..              ...                              ...            ...      ...
# 595             596                              1.0              1        0
# 596             597                              0.0              1        0
# 597             598                              1.0              1        1
# 598             599                              0.0              1        1
# 599             600                              1.0              1        0
#
# ...

# %%
dfGDData.shape
# Out:
# (600, 259)

# %%
dfGDData.dtypes
# Out:
# Participant ID                              int64
# 25OHD checked yes (1) or no (0)           float64
# Screened 10 2                               int64
# GCT10 2                                     int64
# Date Form Signed                   datetime64[ns]
#                                         ...
# Transposition of Great arteries            object
# Septal defect                              object
# Other cardiac anomaly                      object
# Epidural                                   object
# Spinal                                     object
# Length: 259, dtype: object

# %%
list(dfGDData.columns)
# Out:
# ['Participant ID',
#  '25OHD checked yes (1) or no (0)',
#  'Screened 10 2',
#  'GCT10 2',
#  'Date Form Signed',
#  'systolic BP (mmHg) V1',
#  'diastolic BP (mmHg) V1',
#  'Pulse (bpm) V1',
#  'Weight (kg) V1',
#  'Height (cm) V1',
#  'Height (m) V1',
#  'BMI V1',
#  'BMI (kg/m2) V1',
#  'Smoking',
#  'Smoking 123',
#  'Smoking 10 V1',
#  'Alcohol Intake V1',
#  'Ethnicity V1',
#  'White 10 V1',
#  'Previous GDM V1',
#  'PreviousGDM10 V1',
#  'PMHx V1',
#  'Chronic Illness V1',
#  'Medications V1',
#  'Meds 10 V1',
#  'Age>30',
#  'Age >30 10',
#  'BMI (kg/m2) V1 2',
#  'BMI>30',
#  'Obese 10',
#  'Overweight 10',
#  'Overweight 123',
#  'Hx GDM, glycosuria, 1st degree rel',
#  'HighRisk 10',
#  'List used',
#  'Screening method',
#  'GCT 10',
#  'Vit D List used',
#  '25OHD checked',
#  '25OHD 10',
#  '1st DASS score >33',
#  'Ref to Psych',
#  'V1 Gestational Age',
#  'EDD V1',
#  'V1 HbA1c (mmol/mol)',
#  'V1 HBa1C <48 mmol/mol',
#  'WCC',
#  'V1 Hb',
#  'V1 Platelet',
# ...

# %%
missingvalues_percentage = dfGDData.isna().sum().sort_values(ascending= False)/len(dfGDData)
missingvalues_percentage
# Out:
# Lost to f/u                    1.0
# V3 GA                          1.0
# Miscarriage after 28/40        1.0
# Miscarriage.1                  1.0
# Miscarriage before 28/40 v2    1.0
#                               ...
# Age>30                         0.0
# Age >30 10                     0.0
# BMI (kg/m2) V1 2               0.0
# BMI>30                         0.0
# Participant ID                 0.0
# Length: 259, dtype: float64

# %%
plt.figure(figsize=(30,35))
plt.xticks(rotation=75)
plt.yticks(fontsize=10)
plt.title("Percentage of Missing Values per Column",fontsize=15)

b=sns.barplot(x=missingvalues_percentage[missingvalues_percentage>0.0],y=missingvalues_percentage[missingvalues_percentage>0.0].index)
b.set_ylabel("Columns Names",fontsize= 15)
b.set_xlabel("Percentage missing values",fontsize= 15)
plt.show()

# %%
dfGDData.drop(columns=['GCT10 2', 'Height (m) V1','BMI V1','Smoking','Smoking 10 V1','White 10 V1','Previous GDM V1','Meds 10 V1','Age >30 10','BMI (kg/m2) V1 2','BMI>30','Obese 10','Overweight 10','Overweight 123','Hx GDM, glycosuria, 1st degree rel','GCT 10','25OHD checked','25OHD 10'],axis=1,inplace=True)
dfGDData.drop(columns=['Ref to psych','V1 HbA1c (mmol/mol)','V1 HBa1C <48 mmol/mol','V1 Hb','V1 Creatinine', 'V1 ALT','V1 CRP','V1 PCR','GCT10 screening visit','GCT','GCT 1h value >7.5mM','GCT 1h value >7.2mM 10', 'GCT 1h value >7.5mM 10', 'GCT 1h value >7.8mM 10','GCT Ref to DNS?','GCT Ref to DNS 10','OGTT performed','OGTT 10 V3'],inplace=True)
dfGDData.drop(columns=[ 'OGTT 0h value high 10','OGTT 1h value high 10','OGTT 1h value high 10.1','OGTT values high','OGTT high 10','GCT 1h value >7.5mM 10.1','GCT OGTT high 10','OGTT Ref to DNS 10','GCT Ref to DNS 10.1','Ref to DNS 10','Miscarriage before 28/40 2','Withdrew before 28/40 2'],axis=1,inplace=True)
dfGDData.drop(columns=['V3 GA','Miscarried <28/40','Miscarried >28/40','V3 HbA1c','V3 Hb','V3 Creat','V3 CRP', 'V3 U PCR','V3 AC <35 cm','AC >350mm 10','m Weight (kg) V1','m Weight (kg) V3','Weight change','Weight change (%)','systolic BP (mmHg) V1.1','systolic BP (mmHg) V3.1','sBP change','BP change (%)'],inplace=True)
dfGDData.drop(columns=['HbA1c change','HbA1c change >3 mmol/mol 10','HbA1c Change (%)','HbA1c rise >10%','HbA1c rise >5%','Hb change','Hb change (%)','Creat change','Creat change (%)','V3 ALT.1','ALT change','ALT change (%)','CRP change','CRP change (%)','PCR change','PCR change (%)'],axis=1,inplace=True)
dfGDData.drop(columns=['Date of Data Collection.1','Miscarriage','Lost to f/u', 'Nutrition 10','Glucose lowering therapies','Gestational hypertension','Pre-eclampsia','Eclampsia','HELLP','HELLP 10','Induction','Instrumentation 10','Date of Delivery','Miscarriage before 28/40 v2','Miscarriage.1','Miscarriage after 28/40'],inplace=True)
dfGDData.drop(columns=['Still-birth 10','Birth Injury','Birth weight >4kg', 'BW >4kg 10', 'BW >4.5kg 10', 'BW <2.5kg 10','Brachial plexus injury','Plexus injury 10','Other nerve injury','Clavicular fracture','Humeral fracture','Skull fracture','Other birth injury'],axis=1,inplace=True)
dfGDData.drop(columns=['Perinatal death', 'Perinatal death 10', 'Fetal hypoglycaemia', 'Fetal hypoglycaemia 10', 'Fetal jaundice', 'Fetal phototherapy','Surfactant use','RR>60 10', 'SCBU','Cong malformation','Spina bifida','Cleft palate','Cleft Lip','Hydrocephalus','Cardiac murmur', 'Cardiac anomaly', 'Tetralogy of Fallot','Transposition of Great arteries', 'Septal defect', 'Other cardiac anomaly'],inplace=True)

# %%
missingvalues_percentage = dfGDData.isna().sum().sort_values(ascending= False)/len(dfGDData)
missingvalues_percentage
# Out:
# Cause of fetal death       0.996667
# Twins weight               0.991667
# Insulin/Metformin          0.950000
# Medications V1             0.948333
# Date Prescription sent?    0.858333
#                              ...
# Ethnicity V1               0.000000
# Alcohol Intake V1          0.000000
# BMI (kg/m2) V1             0.000000
# Screening DNA 2            0.000000
# Participant ID             0.000000
# Length: 128, dtype: float64

# %%
plt.figure(figsize=(30,35))
plt.xticks(rotation=75)
plt.yticks(fontsize=10)
plt.title("Percentage of Missing Values per Column",fontsize=15)

b=sns.barplot(x=missingvalues_percentage[missingvalues_percentage>0.0],y=missingvalues_percentage[missingvalues_percentage>0.0].index)
b.set_ylabel("Columns Names",fontsize= 15)
b.set_xlabel("Percentage missing values",fontsize= 15)
plt.show()

# %%
dfGDData.to_excel("GDM_DataDivers.xlsx",sheet_name = "GDM_Data",index=False)

# %%
dfGDDataStage=pd.read_excel("GDM_DataDivers.xlsx",sheet_name = "GDM_Data")

# %%
list(dfGDDataStage.columns)
# Out:
# ['Participant ID',
#  '25OHD checked yes (1) or no (0)',
#  'Screened 10 2',
#  'Date Form Signed',
#  'systolic BP (mmHg) V1',
#  'diastolic BP (mmHg) V1',
#  'Pulse (bpm) V1',
#  'Weight (kg) V1',
#  'Height (cm) V1',
#  'BMI (kg/m2) V1',
#  'Smoking 123',
#  'Alcohol Intake V1',
#  'Ethnicity V1',
#  'PreviousGDM10 V1',
#  'PMHx V1',
#  'Chronic Illness V1',
#  'Medications V1',
#  'Age>30',
#  'HighRisk 10',
#  'List used',
#  'Screening method',
#  'Vit D List used',
#  '1st DASS score >33',
#  'Ref to Psych',
#  'V1 Gestational Age',
#  'EDD V1',
#  'WCC',
#  'V1 Platelet',
#  'V1 Calcium',
#  'V1 Albumin',
#  'V1 U albumin',
#  'V1 U protein',
#  'V1 U creatinine',
#  'V1 US EDD',
#  'EDD in keeping with LMP?',
#  'EDD estimation method',
#  'V1 25OHD value (nmol/L)',
#  'Date 25OHD result received',
#  'Prescription for Caltrate sent?',
#  'Date Prescription sent?',
#  'GDM screening performed? V2',
#  'Miscarriage before 28/40',
#  'Withdrew before 28/40',
# ...

# %%
dfGDDataStage.drop(columns=['Caesarean'], inplace=True)
dfGDDataStage.rename(columns={'EDD in keeping with LMP?': 'EDDEqLMP', 'EDD estimation method': 'EDDMethod','LSCS 10':'Caesarean','Ethnicity V1':'Ethnicity','Fetal jaundice 10':'FetalJaundice','1h glucose':'Glucose_1h'}, inplace=True)
dfGDDataStage.rename(columns={'GHP 10': 'GestationalHP', 'Glucose lowering therapy 10': 'GlucoseTherapy','V1 HbA1c (mmol/mol).1':'HB1AC_V1','V3 HbA1c.1':'HB1AC_V3','V1 Hb.1':'Hemoglobin_V1','V3 Hb.1':'Hemoglobin_V3','HbA1c V2':'HB1AC_V2'}, inplace=True)
dfGDDataStage.rename(columns={ 'Height (cm) V1': 'Height_cms', 'Induction 10': 'Labor_Induced','Instrumentation':'Instrument_Delivery', 'Insulin 10':'On_Insulin','Metformin 10':'On_Metformin','Medications V1':'Medications_All'}, inplace=True)

# %%
dfGDDataStage.drop(columns=[ 'Fetal phototherapy 10','Insulin/Metformin','List used','Vit D List used'], inplace=True)

# %%
dfGDDataStage['EDDEqLMP'].fillna('NR',inplace=True)
dfGDDataStage['EDDMethod'].fillna('NR',inplace=True)
dfGDDataStage['FetalJaundice'].fillna('NR',inplace=True)
dfGDDataStage['Glucose_1h'].fillna('NR',inplace=True)
dfGDDataStage['GestationalHP'].fillna('NR',inplace=True)
dfGDDataStage['HB1AC_V1'].fillna('NR',inplace=True)
dfGDDataStage['HB1AC_V3'].fillna('NR',inplace=True)
dfGDDataStage['Hemoglobin_V1'].fillna('NR',inplace=True)
dfGDDataStage['Hemoglobin_V3'].fillna('NR',inplace=True)
dfGDDataStage['HB1AC_V2'].fillna('NR',inplace=True)
dfGDDataStage['Labor_Induced'].fillna('NR',inplace=True)
dfGDDataStage['Instrument_Delivery'].fillna('NR',inplace=True)
dfGDDataStage['On_Insulin'].fillna('NR',inplace=True)
dfGDDataStage['On_Metformin'].fillna('NR',inplace=True)
dfGDDataStage['Spinal'].fillna('NR',inplace=True)
dfGDDataStage['Caesarean'].fillna('NR',inplace=True)

# %%
dfGDDataStage['Emergency'].fillna(0,inplace=True)
dfGDDataStage['Epidural'].fillna('No',inplace=True)
dfGDDataStage['GlucoseTherapy'].fillna(0,inplace=True)

# %%
dfGDDataStage['Epidural'] = dfGDDataStage['Epidural'].str.title()

# %%
dfGDDataStage['Spinal'] = dfGDDataStage['Spinal'].str.replace('No (GA)','No',regex=True)

# %%
dfGDDataStage['Ethnicity']=dfGDDataStage.Ethnicity.str.replace(r" \(.*\)","", regex=True)

# %%
dfGDDataStage
# Out:
#      Participant ID  25OHD checked yes (1) or no (0)  Screened 10 2  \
# 0                 1                              NaN              1
# 1                 2                              NaN              1
# 2                 3                              NaN              1
# 3                 4                              NaN              1
# 4                 5                              NaN              1
# ..              ...                              ...            ...
# 595             596                              1.0              1
# 596             597                              0.0              1
# 597             598                              1.0              1
# 598             599                              0.0              1
# 599             600                              1.0              1
#
#     Date Form Signed  systolic BP (mmHg) V1  diastolic BP (mmHg) V1  \
# 0         2013-10-02                    114                      58
# ...

# %%
dfGDDataStage.to_excel("GDM_DataDivers.xlsx",sheet_name = "GDM_Data",index=False)

# %%
# Drop columns .Valid data not present
dfGDDataStage.drop(columns=['Cause of fetal death','V1 U creatinine','V3 U Creat','Date 25OHD result received','Date Form Signed','Date Prescription sent?','Shoulder dystocia'], inplace=True)


#Renaming columns for better readability
dfGDDataStage.rename(columns={'Chronic Illness V1': 'Chronic Illness','Cong malformation 10':'Cong malformation','V1 Creatinine':'Creatinine_V1','V3 Creat':'Creatinine_V3','V1 CRP':'CRP_V1','V3 CRP':'CRP_V3'}, inplace=True)
dfGDDataStage.rename(columns={'Prescription for Caltrate sent?':'Caltrate','Delivered before 36/40 10':'Delivered before 36/40','Diagnosed with Vit D Deficiency':'Vit D Deficiency','Dystocia 10':'Dystocia'}, inplace=True)
dfGDDataStage.rename(columns={'Eclampsia 10':'Eclampsia','Pre-eclampsia 10':'Pre eclampsia'}, inplace=True)

# %%
# Handling NULL values, when needed

dfGDDataStage['Cong malformation'].fillna(0,inplace=True)
dfGDDataStage['Caltrate'].fillna('No',inplace=True) 
dfGDDataStage['Vit D Deficiency'].fillna('NR',inplace=True)  
dfGDDataStage['Eclampsia'].fillna('NR',inplace=True)
dfGDDataStage['Pre eclampsia'].fillna('NR',inplace=True)

# %%
# Avoid noice in the data

dfGDDataStage['Caltrate'].replace('No (Miscarried)','No')

# Avoid noice in the data - Prescription for Caltrate sent?

dfGDDataStage['Vit D Deficiency']=dfGDDataStage['Vit D Deficiency'].str.startswith(('Yes','yes')).replace([True,False],['Yes','No'])

# %%
# Avoid noice in the data - Date of Visit 3
# Keeping only date values and removing all string value

def valid_date(date):
    try:
        pd.to_datetime(date)
        return date
    except ValueError:
        return np.nan
    
# Replace invalid dates with `NaN`
dfGDDataStage['Date of Visit 3'] = dfGDDataStage['Date of Visit 3'].apply(valid_date)
dfGDDataStage['Date of Visit 3']
# Out:
# 0     2014-03-10
# 1     2014-03-24
# 2     2014-02-24
# 3     2014-03-24
# 4     2014-03-10
#          ...
# 595   2016-03-21
# 596   2016-04-25
# 597   2016-04-04
# 598          NaT
# 599   2016-04-11
# Name: Date of Visit 3, Length: 600, dtype: datetime64[ns]

# %%
dfGDDataStage
# Out:
#      Participant ID  25OHD checked yes (1) or no (0)  Screened 10 2  \
# 0                 1                              NaN              1
# 1                 2                              NaN              1
# 2                 3                              NaN              1
# 3                 4                              NaN              1
# 4                 5                              NaN              1
# ..              ...                              ...            ...
# 595             596                              1.0              1
# 596             597                              0.0              1
# 597             598                              1.0              1
# 598             599                              0.0              1
# 599             600                              1.0              1
#
#      systolic BP (mmHg) V1  diastolic BP (mmHg) V1  Pulse (bpm) V1  \
# 0                      114                      58              73
# ...

# %%
# writing to the excel 

dfGDDataStage.to_excel("GDM_DataDivers.xlsx",sheet_name = "GDM_Data",index=False)

# %%
#Filling in the Null Values
dfGDDataStage['Twins 10'].fillna('NR',inplace=True)
dfGDDataStage['Twins weight'].fillna('NR',inplace=True)
dfGDDataStage['V1 Albumin'].fillna('NR',inplace=True)
dfGDDataStage['V1 U albumin'].fillna('NR',inplace=True)
dfGDDataStage['V3 Albumin'].fillna('NR',inplace=True)
dfGDDataStage['V3 U Alb'].fillna('NR',inplace=True)
dfGDDataStage['V1 Platelet'].fillna('NR',inplace=True)
dfGDDataStage['V3 Platelet'].fillna('NR',inplace=True)
dfGDDataStage['V1 Calcium'].fillna('NR',inplace=True)
dfGDDataStage['V3 Calcium'].fillna('NR',inplace=True)
dfGDDataStage['V1 25OHD value (nmol/L)'].fillna('NR',inplace=True)
dfGDDataStage['V3 25OHD value'].fillna('NR',inplace=True)
dfGDDataStage['V1 U protein'].fillna('NR',inplace=True)
dfGDDataStage['V3 Abdominal Circumference'].fillna('NR',inplace=True)
dfGDDataStage['1st DASS score >33'].fillna('NR',inplace=True)
dfGDDataStage['Attended Visit 3 10'].fillna('NR',inplace=True)
dfGDDataStage['V3 U Prot'].fillna('NR',inplace=True)
dfGDDataStage['V3 WCC'].fillna('NR',inplace=True)
dfGDDataStage['WCC'].fillna('NR',inplace=True)
dfGDDataStage['Withdrew before 28/40'].fillna('NR',inplace=True)
dfGDDataStage['Withdrew after 28/40 10'].fillna('NR',inplace=True)
dfGDDataStage['Dx with GDM'].fillna('NR',inplace=True)

# %%
#Removing Noise in Data
dfGDDataStage['V1 U albumin'] = dfGDDataStage['V1 U albumin'].str.replace('[^\d]+', '', regex=True)
dfGDDataStage['V1 U albumin'] = pd.to_numeric(dfGDDataStage['V1 U albumin'], errors='coerce')

# %%
#Removing Noise in Data
dfGDDataStage['V3 Albumin'] = dfGDDataStage['V3 Albumin'].replace('[^\d\.]+', 'NR', regex=True)

# %%
#Removing Noise in Data
dfGDDataStage['V3 U Alb'] = dfGDDataStage['V3 U Alb'].astype(str)
dfGDDataStage['V3 U Alb'] = dfGDDataStage['V3 U Alb'].str.replace('[^\d]+', '', regex=True)
dfGDDataStage['V3 U Alb'] = dfGDDataStage['V3 U Alb'].str.replace('[^0-9\.]+', '', regex=True)
dfGDDataStage['V3 U Alb'] = pd.to_numeric(dfGDDataStage['V3 U Alb'], errors='coerce')

# %%
#Removing Noise in Data
dfGDDataStage['1st DASS score >33'] = dfGDDataStage['1st DASS score >33'].replace(['Couldn’t read/write', 'Didn’t fill it in'], 'NR')

# %%
#Removing Noise in Data
def to_days(x):
    try:
        if '+' in x:
            weeks, days = x.split('+')
            return int(weeks) * 7 + int(days)
        else:
            return int(x)
    except:
        return None

# %%
#Removing Noise in Data
dfGDDataStage['V1 Gestational Age'] = dfGDDataStage['V1 Gestational Age'].astype(str).apply(to_days)

# %%
#Removing Noise in Data
def avg_twins_weight(x):
    if x == 'NR':
        return x
    elif isinstance(x, str) and ',' in x:
        # split on comma
        nums = x.split(',')
    elif isinstance(x, str) and '/' in x:
        # split on slash
        nums = x.split('/')
    elif isinstance(x, str):
        # split on whitespace
        nums = x.split()
    else:
        return np.nan
    
    # convert to float and take the average
    nums = [float(n.replace(',', '.')) for n in nums]
    avg_weight = sum(nums) / len(nums)
    return round(avg_weight, 2)

# %%
#Removing Noise in Data
dfGDDataStage['Twins weight'] = dfGDDataStage['Twins weight'].apply(avg_twins_weight)

# %%
#Removing Noise in Data
dfGDDataStage['V1 25OHD value (nmol/L)'] = dfGDDataStage['V1 25OHD value (nmol/L)'].replace(['Sample lost by lab'], 'NR')

# %%
#Removing Noise in Data
dfGDDataStage['V3 25OHD value'] = dfGDDataStage['V3 25OHD value'].replace(['Sample not sent', 'Incorrect sample','No Sample reci','Sample lost','Insufficent'], 'NR')

# %%
#Renaming Columns
dfGDDataStage.rename(columns={'Twins 10': 'Twins','V1 Albumin':'Albumin_V1','V1 U albumin':'U Albumin_V1','V3 Albumin':'Albumin_V3','V3 U Alb':'U Albumin_V3','V1 Platelet':'Platelet_V1'}, inplace=True)
dfGDDataStage.rename(columns={'V3 Platelet': 'Platelet_V3','V1 Calcium':'Calcium_V1','V3 Calcium':'Calcium_V3','V1 25OHD value (nmol/L)':'25OHD value (nmol/L)_V1','V3 25OHD value':'25OHD value_V3','V1 U protein':'U Protein_V1','V3 Abdominal Circumference':'Abdominal Circumference_V3'}, inplace=True)
dfGDDataStage.rename(columns={'Attended Visit 3 10': 'Attended Visit 3','V3 U Prot':'U Protein_V3','V3 WCC':'White Cell Count_V3','WCC':'White Cell Count','Dx with GDM':'GDM Diagonised','V1 Gestational Age':'Gestational Age_V1'}, inplace=True)

# %%
#Write TO excel
dfGDDataStage.to_excel("GDM_DataDivers.xlsx",sheet_name = "GDM_Data",index=False)

# %%
#Removing Noise in Data
dfGDDataStage['GDM Diagonised'].replace('N0', 'No', inplace=True)

# %%
#Removing Noise in Data
dfGDDataStage['GDM Diagonised'].unique()
# Out:
# array(['No', 'Yes', 'NR'], dtype=object)

# %%
#Write TO excel
dfGDDataStage.to_excel("GDM_DataDivers.xlsx",sheet_name = "GDM_Data",index=False)

# %%
dfGDDataStage['GDM Diagonised'].unique()
# Out:
# array(['No', 'Yes', 'NR'], dtype=object)

# %%
dfGDDataStage.shape
# Out:
# (600, 116)

# %%
dfGDDataStage['GDM Diagonised'].unique()
# Out:
# array(['No', 'Yes', 'NR'], dtype=object)

# %%
dfGDDataStage=pd.read_excel("GDM_DataDivers.xlsx",sheet_name = "GDM_Data")

# %%
#drop columns

dfGDDataStage.drop(columns=['Miscarried 10'], inplace=True)
dfGDDataStage.drop(columns=['Number obstetric clinics'], inplace=True)
dfGDDataStage.drop(columns=['OGTT Ref to DNS'], inplace=True)
dfGDDataStage.drop(columns=['PMHx V1'], inplace=True)
dfGDDataStage.drop(columns=['Ref to Psych'], inplace=True)

# %%
#rename column names

dfGDDataStage.rename(columns={'V3 U PCR': 'U PCR', 'Smoking 123 ': 'Smoking','SCBU 10' : 'SCBU'}, inplace=True)

# %%
#Write TO excel
dfGDDataStage.to_excel("GDM_DataDivers.xlsx",sheet_name = "GDM_Data",index=False)

# %%
#replace null value with 'NR'

dfGDDataStage['OGTT 0h value'].fillna('NR',inplace=True)
dfGDDataStage['Nutritional counselling'].fillna('No',inplace=True)
dfGDDataStage['OGTT 1h value'].fillna('NR',inplace=True)
dfGDDataStage['OGTT 2h value'].fillna('NR',inplace=True)
dfGDDataStage['V1 PCR.1'].fillna('NR',inplace=True)
dfGDDataStage['V3 U PCR.1'].fillna('NR',inplace=True)
dfGDDataStage['3rd visit DASS >33'].fillna('NR',inplace=True)
dfGDDataStage['RR>60'].fillna('NR',inplace=True)
dfGDDataStage['SCBU'].fillna('NR',inplace=True)
dfGDDataStage['Smoking 123'].fillna('NR',inplace=True)
dfGDDataStage['Still-birth'].fillna('NR',inplace=True)
dfGDDataStage['Took Vit D Supplements'].fillna('NR',inplace=True)
dfGDDataStage['Total bilirubin'].fillna('NR',inplace=True)

# %%
# replace non-numeric values with 'NR' in column_name

dfGDDataStage['Total bilirubin'] = pd.to_numeric(dfGDDataStage['Total bilirubin'], errors='coerce').fillna('NR')

# %%
dfGDDataStage
# Out:
#      Participant ID  25OHD checked yes (1) or no (0)  Screened 10 2  \
# 0                 1                              NaN              1
# 1                 2                              NaN              1
# 2                 3                              NaN              1
# 3                 4                              NaN              1
# 4                 5                              NaN              1
# ..              ...                              ...            ...
# 595             596                              1.0              1
# 596             597                              0.0              1
# 597             598                              1.0              1
# 598             599                              0.0              1
# 599             600                              1.0              1
#
#      systolic BP (mmHg) V1  diastolic BP (mmHg) V1  Pulse (bpm) V1  \
# 0                      114                      58              73
# ...

# %%
#Write TO excel

dfGDDataStage.to_excel("GDM_DataDivers.xlsx",sheet_name = "GDM_Data",index=False)

# %%
# Replacing the column names
dfGDDataStage = dfGDDataStage.rename(columns={'Participant ID': 'Participant_ID'})
dfGDDataStage = dfGDDataStage.rename(columns={'Weight (kg) V1': 'WeightinV1'})
dfGDDataStage = dfGDDataStage.rename(columns={'Weight (kg) V3': 'WeightinV3'})
dfGDDataStage = dfGDDataStage.rename(columns={'Pulse (bpm) V1': 'PulseinV1'})
dfGDDataStage = dfGDDataStage.rename(columns={'Pulse (bpm) V3': 'PulseinV3'})
dfGDDataStage = dfGDDataStage.rename(columns={'diastolic BP (mmHg) V1': 'diastolicBP_V1'})
dfGDDataStage = dfGDDataStage.rename(columns={'diastolic BP (mmHg) V3': 'diastolicBP_V3'})
dfGDDataStage = dfGDDataStage.rename(columns={'systolic BP (mmHg) V1': 'systolicBP_V1'})
dfGDDataStage = dfGDDataStage.rename(columns={'systolic BP (mmHg) V3': 'systolicBP_V3'})
dfGDDataStage = dfGDDataStage.rename(columns={'Antenatal steroid use': 'Antenatal_steroid_use'})
dfGDDataStage = dfGDDataStage.rename(columns={'BMI (kg/m2) V1': 'BMIinV1'})
dfGDDataStage = dfGDDataStage.rename(columns={'Birth Injury 10': 'BirthInjury'})
dfGDDataStage = dfGDDataStage.rename(columns={'Birth weight (kg)': 'BirthWeight'})
dfGDDataStage = dfGDDataStage.rename(columns={'Attended GDM clinics': 'Attended_GDM_clinics'})
dfGDDataStage = dfGDDataStage.rename(columns={'HighRisk 10': 'HighRisk'})
dfGDDataStage = dfGDDataStage.rename(columns={'V1 ALT.1': 'ALT_V1'})
dfGDDataStage = dfGDDataStage.rename(columns={'V3 ALT': 'ALT_V3'})
dfGDDataStage = dfGDDataStage.rename(columns={'Apgar 1 minute': 'Apgar_1min'})
dfGDDataStage = dfGDDataStage.rename(columns={'Apgar 3 minutes': 'Apgar_3min'})
dfGDDataStage = dfGDDataStage.rename(columns={'GDM screening performed?': 'GDM_performed'})
dfGDDataStage = dfGDDataStage.rename(columns={'GDM screening performed? V2': 'GDM_performedV2'})
dfGDDataStage = dfGDDataStage.rename(columns={'Age>30': 'Age_gt_30'})

# %%
mask = (dfGDDataStage['Glucose_1h'].astype(str) == 'NR') & \
       (dfGDDataStage['OGTT 0h value'].astype(str) == 'NR') & \
       (dfGDDataStage['OGTT 1h value'].astype(str) == 'NR') & \
       (dfGDDataStage['OGTT 2h value'].astype(str) == 'NR') & \
       (dfGDDataStage['GDM Diagonised'].astype(str) == 'NR')

# filter out the rows where the mask is True
dfGDDataStage = dfGDDataStage[~mask]
